# %%
from PIL import Image
import matplotlib.pyplot as plt
import canny

img = Image.open('../image_assets/test_a.jpg').convert('L')  # 'L' mode converts to grayscale
img = img.resize((128, 128))
img_array = [np.array(img, dtype=np.float32)]
print(img_array[0].shape)

plt.imshow(img, cmap='gray')
plt.axis("off")
plt.show()

detector = canny.cannyEdgeDetector(img_array, sigma=1.4, kernel_size=5, lowthreshold=0.09, highthreshold=0.17, weak_pixel=100)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[53], line 3
#       1 from PIL import Image
#       2 import matplotlib.pyplot as plt
# ----> 3 import canny
#       5 img = Image.open('../image_assets/test_a.jpg').convert('L')  # 'L' mode converts to grayscale
#       6 img = img.resize((128, 128))
#
# ModuleNotFoundError: No module named 'canny'

# %%
imgs_final = detector.detect()
img = imgs_final[0]
plt.imshow(img, cmap='gray')
plt.axis("off")
plt.show()
